# %% [markdown]
# # ex1_scientific1
#
# ## Nội dung bài
# Hiển thị ngẫu nhiên $N=50$ hình tròn:
# + Tâm $c_i = (x_i,y_i)$ ngẫu nhiên với $x_i,y_i \in \left[0,1 \right]$
# + Màu sắc $color_i$ ngẫu nhiên với $color_i \in \left[0,1 \right]$
# + Diện tích $area_i = \pi * r_i^2$ với sinh ngẫu nhiên $r_i \in \left[0,1 \right]$
# ## Bài làm

# %% [markdown]
# ### Import thư viện

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display

# %% [markdown]
# ### Sinh ngẫu nhiên hình tròn

# %%
# Mã kiểm tra dữ liệu
print(f'+ x: len={len(x):d} , [{min(x):.2f} , {max(x):.2f}] : 10 samples [{x[0:10]}]')
print(f'+ y: len={len(y):d} , [{min(y):.2f} , {max(y):.2f}] : 10 samples [{y[0:10]}]')
print(f'+ color: len={len(color):d} , [{min(color):.2f} , {max(color):.2f}] : 10 samples [{color[0:10]}]')
print(f'+ area: len={len(area):d} , [{min(area):.2f} , {max(area):.2f}] : 10 samples [{area[0:10]}]')
# Out:
# + x: len=50 , [0.00 , 0.99] : 10 samples [[0.38439738 0.68694681 0.96047517 0.38713204 0.24300429 0.2632784
#  0.8434734  0.10601925 0.10425149 0.90560076]]
# + y: len=50 , [0.00 , 0.98] : 10 samples [[0.72983713 0.82433866 0.8022537  0.63038525 0.05601781 0.66880476
#  0.83975027 0.62186691 0.03884248 0.76122307]]
# + color: len=50 , [0.01 , 0.99] : 10 samples [[0.12528151 0.46569802 0.42597909 0.63312045 0.76673382 0.98497727
#  0.35651973 0.69159912 0.94139634 0.31747635]]
# + area: len=50 , [0.33 , 702.31] : 10 samples [[2.41753329e+02 7.02307793e+02 5.45353515e+02 7.97729986e+01
#  1.54311112e+02 3.58314394e-01 1.87236478e+02 5.37750456e+02
#  1.82040594e+02 3.76749656e-01]]

# %% [markdown]
# ### Hiển thị đồ thị

# %%
# %matplotlib inline
plt.scatter(x,y,s=area,c=color,alpha=0.5)
plt.show()

# %% [markdown]
# # Kết thúc
